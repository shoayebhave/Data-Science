# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv')
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.shape
# Out:
# (83439, 48)

# %%
# Show how many columns, rows in jupyter notebook we want to see
pd.set_option('display.max_columns',47)
pd.set_option('display.max_rows',47)

# %%
schema_df=pd.read_csv('survey_results_schema.csv')
schema_df
# Out:
#        qid          qname                                           question  \
# 0    QID16             S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12       MetaInfo                                  Browser Meta Info
# 2     QID1             S1  <span style="font-size:22px; font-family: aria...
# 3     QID2     MainBranch  Which of the following options best describes ...
# 4    QID24     Employment  Which of the following best describes your cur...
# ..     ...            ...                                                ...
# 43  QID124  Accessibility  Which of the following describe you, if any? P...
# 44  QID125   MentalHealth  Which of the following describe you, if any? P...
# 45  QID131             S6  <span style="font-size:22px;"><strong>Final Qu...
# 46  QID132   SurveyLength  How do you feel about the length of the survey...
# 47  QID133     SurveyEase  How easy or difficult was this survey to compl...
#
#     force_resp  type selector
# ...

# %%
schema_df.loc[[43],'question']
# Out:
# 43    Which of the following describe you, if any? P...
# Name: question, dtype: object

# %%
a=schema_df.set_index('qid')
a
# Out:
#                 qname                                           question  \
# qid
# QID16              S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12        MetaInfo                                  Browser Meta Info
# QID1               S1  <span style="font-size:22px; font-family: aria...
# QID2       MainBranch  Which of the following options best describes ...
# QID24      Employment  Which of the following best describes your cur...
# ...               ...                                                ...
# QID124  Accessibility  Which of the following describe you, if any? P...
# QID125   MentalHealth  Which of the following describe you, if any? P...
# QID131             S6  <span style="font-size:22px;"><strong>Final Qu...
# QID132   SurveyLength  How do you feel about the length of the survey...
# QID133     SurveyEase  How easy or difficult was this survey to compl...
#
#         force_resp  type selector
# qid
# QID16        False    DB       TB
# ...

# %%
a.sort_index(inplace=True)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['SOComm'].value_counts()
# Out:
# Yes, somewhat      23584
# No, not really     20697
# Neutral            17084
# Yes, definitely    12888
# No, not at all      6633
# Not sure            1433
# Name: SOComm, dtype: int64

# %%
#Indexing
df.loc[[1,2,3],'SOComm']
# Out:
# 1    Yes, definitely
# 2    Yes, definitely
# 3            Neutral
# Name: SOComm, dtype: object

# %%
#Slicing
df.loc[1:2,'DatabaseHaveWorkedWith':'PlatformWantToWorkWith']
# Out:
#   DatabaseHaveWorkedWith DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 1             PostgreSQL                    NaN                    NaN
# 2                 SQLite                 SQLite                 Heroku
#
#   PlatformWantToWorkWith
# 1                    NaN
# 2                    NaN

# %%
df.set_index('DatabaseHaveWorkedWith')
# Out:
#                                                   ResponseId  \
# DatabaseHaveWorkedWith
# PostgreSQL;SQLite                                          1
# PostgreSQL                                                 2
# SQLite                                                     3
# NaN                                                        4
# Elasticsearch;PostgreSQL;Redis                             5
# ...                                                      ...
# Oracle;SQLite                                          83435
# Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite         83436
# DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis        83437
# Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis       83438
# Oracle;PostgreSQL                                      83439
#
#                                                                                          MainBranch  \
# DatabaseHaveWorkedWith
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=83439, step=1)

# %%
#Pandas 2 data type --- 1.DataFrame 2. Series
# 1. DataFrame means 2 dimensional data structure or just rows and columns
#Dictionary


people={
    'First_Name': 'Shoayeb',
    'Last_Name': 'Islam'
}

# %%
#Dictionary with List
people={
    'First_Name': ['Shoayeb','Himel','Rana'],
    'Last_Name': ['Islam','Rana','Ahmed']
}

# %%
people['First_Name'][2:]
# Out:
# ['Rana']

# %%
#Dictionary in a dataframe
df1=pd.DataFrame(people)
df1
# Out:
#   First_Name Last_Name
# 0    Shoayeb     Islam
# 1      Himel      Rana
# 2       Rana     Ahmed

# %%
df1['Last_Name']
# Out:
# 0    Islam
# 1     Rana
# 2    Ahmed
# Name: Last_Name, dtype: object

# %%
df1.Last_Name
# Out:
# 0    Islam
# 1     Rana
# 2    Ahmed
# Name: Last_Name, dtype: object

# %%
#For multiple columns return
df1[['First_Name','Last_Name']]
# Out:
#   First_Name Last_Name
# 0    Shoayeb     Islam
# 1      Himel      Rana
# 2       Rana     Ahmed

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# 2. Series is a list of data or rows of being single column

type(df1['Last_Name'])
# Out:
# pandas.core.series.Series

# %%
df1.columns
# Out:
# Index(['First_Name', 'Last_Name'], dtype='object')

# %%
#Iloc allows as to access rows by integer location
#iloc[[rows],columns]
df1.iloc[0]
# Out:
# First_Name    Shoayeb
# Last_Name       Islam
# Name: 0, dtype: object

# %%
df1.iloc[[0,1]]
# Out:
#   First_Name Last_Name
# 0    Shoayeb     Islam
# 1      Himel      Rana

# %%
df1.iloc[[0, 1], 1]
# Out:
# 0    Islam
# 1     Rana
# Name: Last_Name, dtype: object

# %%
#loc is searching by label or index
df1.loc[0]
# Out:
# First_Name    Shoayeb
# Last_Name       Islam
# Name: 0, dtype: object

# %%
#email is the column label so in loc there is no use of column index interger like iloc ,in loc there is 
#directly need column name as label so column name need actual name and row row is just index

df1.loc[[1,2], 'Last_Name']
# Out:
# 1     Rana
# 2    Ahmed
# Name: Last_Name, dtype: object

# %%
df1.loc[[1,2], ['Last_Name','First_Name']]
# Out:
#   Last_Name First_Name
# 1      Rana      Himel
# 2     Ahmed       Rana

# %%
df1.set_index('Last_Name')
# Out:
#           First_Name
# Last_Name
# Islam        Shoayeb
# Rana           Himel
# Ahmed           Rana

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df1.loc[1]
# Out:
# First_Name    Himel
# Last_Name      Rana
# Name: 1, dtype: object
